# %% [markdown]
# <a href="https://colab.research.google.com/github/aycaaozturk/Image-Based-Detection-of-Nail-Melanoma-Using-Deep-Learning-Techniques/blob/main/YOLO_train_for_BB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Nov 10 08:26:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip list | grep torch
# Out:
# torch                                    2.8.0+cu126
# torchao                                  0.10.0
# torchaudio                               2.8.0+cu126
# torchdata                                0.11.0
# torchsummary                             1.5.1
# torchtune                                0.6.1
# torchvision                              0.23.0+cu126

# %%
# %pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 39.5/235.7 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/all nails together"
# Out:
# data.yaml  test  train	valid

# %%
# !yolo detect train data="/content/drive/My Drive/all nails together/data.yaml" model=yolov8n.pt epochs=20 imgsz=640 batch=8
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train data="/content/drive/My Drive/all nails together/data.yaml" model=yolov8n.pt epochs=20 imgsz=640 batch=16
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train data="/content/drive/My Drive/all nails together/data.yaml" model=yolov8n.pt epochs=20 imgsz=640 batch=32
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train data="/content/drive/My Drive/all nails together/data.yaml" model=yolov8n.pt epochs=50 imgsz=640 batch=8
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train data="/content/drive/My Drive/all nails together/data.yaml" model=yolov8n.pt epochs=50 imgsz=640 batch=16
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train data="/content/drive/My Drive/all nails together/data.yaml" model=yolov8n.pt epochs=50 imgsz=640 batch=32
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train data="/content/drive/My Drive/all nails together/data.yaml" model=yolov8n.pt epochs=100 imgsz=640 batch=8
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls
# Out:
# sample_data

# %%
# !yolo detect train data="/content/drive/My Drive/yolov8 format all datasets/data.yaml" model=yolov8n.pt epochs=100 imgsz=640 batch=32
# Out:
# Ultralytics 8.3.209 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %%
# !yolo detect train data="/content/drive/My Drive/yolov8 format all datasets/data.yaml" model=yolov8n.pt epochs=20 imgsz=640 batch=32
# Out:
# ...
# Ultralytics 8.3.211 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...
